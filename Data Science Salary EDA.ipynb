# %% [markdown]
# # Salaries Exercise

# %% [markdown]
# In this notebook, I will do some basic data manipulation using the pandas dataframe. For this, I will be using the Data Science Salary Dataset from Kaggle!

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()

# %%
df=pd.read_csv('ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# # Basic Data Analysis

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# # Checking for null values?

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# # What is the average employee salary?

# %%
df['salary_in_usd'].mean()
# Out:
# 112297.86985172982

# %% [markdown]
# # Top 5 countries where the employees are residing?

# %%
df['employee_residence'].value_counts().head()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# Name: employee_residence, dtype: int64

# %% [markdown]
# # What is the Job title of the highest paid person?

# %%
df[df['salary_in_usd'] == df['salary_in_usd'].max()]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
#
#                    job_title  salary salary_currency  salary_in_usd  \
# 252  Principal Data Engineer  600000             USD         600000
#
#     employee_residence  remote_ratio company_location company_size
# 252                 US           100               US            L

# %% [markdown]
# # What is the job title of the lowest paid person?

# %%
df[df['salary_in_usd'] == df['salary_in_usd'].min()]
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 176         176       2021               MI              FT  Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 176   58000             MXN           2859                 MX             0
#
#     company_location company_size
# 176               MX            S

# %% [markdown]
# # Highest count of jobs and their respective salaries.

# %%
salary_title_df = df.groupby("job_title").agg(
    mean_salary=('salary_in_usd', 'mean'), count_jobs=('job_title', 'count')
).reset_index()
salary_title_df.sort_values(by="count_jobs", ascending=False).head(10)
# Out:
#                      job_title    mean_salary  count_jobs
# 22              Data Scientist  108187.832168         143
# 17               Data Engineer  112725.000000         132
# 12                Data Analyst   92893.061856          97
# 38   Machine Learning Engineer  104880.146341          41
# 48          Research Scientist  109019.500000          16
# 21        Data Science Manager  158328.500000          12
# 16              Data Architect  177873.909091          11
# 7            Big Data Engineer   51974.000000           8
# 41  Machine Learning Scientist  158412.500000           8
# 25    Director of Data Science  195074.000000           7

# %% [markdown]
# # What was the average BasePay of all Job titles per year? (2020-2022) ?

# %%
df.groupby('work_year').salary_in_usd.mean()
# Out:
# work_year
# 2020     95813.000000
# 2021     99853.792627
# 2022    124522.006289
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# # How many unique job titles are there?

# %%
df.job_title.nunique()
# Out:
# 50

# %% [markdown]
# # What are the top 5 most common jobs?

# %%
df.job_title.value_counts().head()
# Out:
# Data Scientist               143
# Data Engineer                132
# Data Analyst                  97
# Machine Learning Engineer     41
# Research Scientist            16
# Name: job_title, dtype: int64

# %% [markdown]
# # How many people have the word Lead in their job title?

# %%
df[df.job_title.str.contains('Lead')].job_title.size
# Out:
# 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB
